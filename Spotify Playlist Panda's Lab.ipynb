# %%
import pandas as pd
import numpy as np

file_upload = pd.read_csv('Most Streamed Spotify Songs 2024 2.csv', encoding='latin1')

file_upload['Release Date']=pd.to_datetime(file_upload['Release Date'], format = "%m/%d/%Y")

# %%
file_upload.dtypes
# Out:
# Track                                 object
# Album Name                            object
# Artist                                object
# Release Date                  datetime64[ns]
# ISRC                                  object
# All Time Rank                         object
# Track Score                          float64
# Spotify Streams                       object
# Spotify Playlist Count                object
# Spotify Playlist Reach                object
# Spotify Popularity                   float64
# YouTube Views                         object
# YouTube Likes                         object
# TikTok Posts                          object
# TikTok Likes                          object
# TikTok Views                          object
# YouTube Playlist Reach                object
# Apple Music Playlist Count           float64
# AirPlay Spins                         object
# SiriusXM Spins                        object
# Deezer Playlist Count                float64
# Deezer Playlist Reach                 object
# Amazon Playlist Count                float64
# Pandora Streams                       object
# Pandora Track Stations                object
# Soundcloud Streams                    object
# Shazam Counts                         object
# TIDAL Popularity                     float64
# Explicit Track                         int64
# dtype: object

# %%
file_upload['Spotify Streams']= file_upload['Spotify Streams'].replace(',','', regex=True)

# %%
file_upload['Spotify Streams'] = pd.to_numeric(file_upload['Spotify Streams'], downcast = 'integer', errors='coerce').fillna(0)

# %%
strings_to_nums = file_upload[['All Time Rank','Spotify Playlist Count','Spotify Playlist Reach','YouTube Views','YouTube Likes'
                               ,'TikTok Posts','TikTok Likes','TikTok Views','YouTube Playlist Reach','AirPlay Spins','SiriusXM Spins'
                               ,'Deezer Playlist Reach','Pandora Streams','Pandora Track Stations','Soundcloud Streams','Shazam Counts']]

# %%
strings_to_nums = strings_to_nums.replace(',','', regex=True)

# %%
strings_to_nums = strings_to_nums.apply(pd.to_numeric, args =('coerce','integer')).fillna('0')
strings_to_nums.dtypes
# Out:
# All Time Rank              int16
# Spotify Playlist Count    object
# Spotify Playlist Reach    object
# YouTube Views             object
# YouTube Likes             object
# TikTok Posts              object
# TikTok Likes              object
# TikTok Views              object
# YouTube Playlist Reach    object
# AirPlay Spins             object
# SiriusXM Spins            object
# Deezer Playlist Reach     object
# Pandora Streams           object
# Pandora Track Stations    object
# Soundcloud Streams        object
# Shazam Counts             object
# dtype: object

# %%
file_upload[['All Time Rank','Spotify Playlist Count','Spotify Playlist Reach','YouTube Views','YouTube Likes','TikTok Posts','TikTok Likes'
             ,'TikTok Views','YouTube Playlist Reach','AirPlay Spins','SiriusXM Spins','Deezer Playlist Reach','Pandora Streams','Pandora Track Stations'
             ,'Soundcloud Streams','Shazam Counts']] = strings_to_nums

# %%
file_upload['Explicit Track']= file_upload['Explicit Track'].astype(bool)

# %%
most_popular = file_upload['Artist'].mode()
print(most_popular)
# Out:
# 0           Drake
# 1    Taylor Swift
# Name: Artist, dtype: object

# %%
result = file_upload[file_upload['Artist'] == 'Drake']
print(result[['Track','Artist','All Time Rank']])
# Out:
#                                         Track Artist  All Time Rank
# 153                            Family Matters  Drake            154
# 175   Rich Baby Daddy (feat. Sexyy Red & SZA)  Drake            176
# 186                        IDGAF (feat. Yeat)  Drake            187
# 191             Jimmy Cooks (feat. 21 Savage)  Drake            192
# 201      First Person Shooter (feat. J. Cole)  Drake            202
# ...                                       ...    ...            ...
# 4099                                 Too Good  Drake           4074
# 4208       All The Parties (feat. Chief Keef)  Drake           4177
# 4227                         Hours In Silence  Drake           4218
# 4276               No Friends In The Industry  Drake           4267
# 4388                          Fear Of Heights  Drake           4358
#
# [63 rows x 3 columns]

# %%
result = file_upload[file_upload['Artist'] == 'Taylor Swift']
print(result[['Track','Artist','All Time Rank']])
# Out:
#                                                   Track        Artist  \
# 16                        Fortnight (feat. Post Malone)  Taylor Swift
# 90                                            Anti-Hero  Taylor Swift
# 239   Is It Over Now? (Taylor's Version) (From The V...  Taylor Swift
# 266                     I Can Do It With a Broken Heart  Taylor Swift
# 452                                        Cruel Summer  Taylor Swift
# ...                                                 ...           ...
# 3909                                      The Black Dog  Taylor Swift
# 4034                                    thanK you aIMee  Taylor Swift
# 4148                                    How Did It End?  Taylor Swift
# 4487            You Belong With Me (Taylorï¿½ï¿½ï¿½s Ve  Taylor Swift
# 4492   Say Don't Go (Taylor's Version) (From The Vault)  Taylor Swift
#
#       All Time Rank
# 16               17
# 90               91
# 239             240
# 266             267
# 452             451
# ...             ...
# 3909           3892
# 4034           4018
# 4148           4140
# 4487           4458
# 4492           4463
#
# [63 rows x 3 columns]

# %%
result = file_upload[file_upload['Artist'] == 'Drake']
print(result['All Time Rank'])
# Out:
# 153      154
# 175      176
# 186      187
# 191      192
# 201      202
#         ...
# 4099    4074
# 4208    4177
# 4227    4218
# 4276    4267
# 4388    4358
# Name: All Time Rank, Length: 63, dtype: int16

# %%
print(result['All Time Rank'].mean())
# Out:
# 1956.095238095238

# %%
result = file_upload[file_upload['Artist'] == 'Taylor Swift']
result['All Time Rank'].mean()
# Out:
# 2340.5079365079364

# %%
print(file_upload['Artist'])
# Out:
# 0        Tommy Richman
# 1       Kendrick Lamar
# 2              Artemas
# 3          Miley Cyrus
# 4               Eminem
#              ...
# 4595       $uicideboy$
# 4596        Atif Aslam
# 4597          Lil Baby
# 4598      Arijit Singh
# 4599         Arcï¿½ï¿½
# Name: Artist, Length: 4600, dtype: object

# %%
d = file_upload['All Time Rank']
d.plot(figsize = (5,5))
# Out:
# <Axes: >

# %%
file_upload.describe()
# Out:
#                         Release Date  All Time Rank  Track Score  \
# count                           4600    4600.000000  4600.000000
# mean   2021-01-27 07:48:18.782608896    2290.678043    41.844043
# min              1987-07-21 00:00:00       1.000000    19.400000
# 25%              2019-07-16 18:00:00    1144.750000    23.300000
# 50%              2022-06-01 00:00:00    2290.500000    29.900000
# 75%              2023-08-11 00:00:00    3436.250000    44.425000
# max              2024-06-14 00:00:00    4998.000000   725.400000
# std                              NaN    1322.878312    38.543766
#
#        Spotify Streams  Spotify Popularity  Apple Music Playlist Count  \
# count     4.600000e+03         3796.000000                  4039.00000
# mean      4.363971e+08           63.501581                    54.60312
# min       0.000000e+00            1.000000                     1.00000
# 25%       6.340627e+07           61.000000                    10.00000
# 50%       2.263761e+08           67.000000                    28.00000
# 75%       6.113563e+08           73.000000                    70.00000
# max       4.281469e+09           96.000000                   859.00000
# std       5.362792e+08           16.186438                    71.61227
#
#        Deezer Playlist Count  Amazon Playlist Count  TIDAL Popularity
# count            3679.000000            3545.000000               0.0
# mean               32.310954              25.348942               NaN
# min                 1.000000               1.000000               NaN
# 25%                 5.000000               8.000000               NaN
# 50%                15.000000              17.000000               NaN
# 75%                37.000000              34.000000               NaN
# max               632.000000             210.000000               NaN
# std                54.274538              25.989826               NaN

# %%
kendrick = file_upload[file_upload['Artist'] == 'Kendrick Lamar']

# %%
kendrick.describe()
# Out:
#               Release Date  All Time Rank  Track Score  Spotify Streams  \
# count                   18      18.000000    18.000000     1.800000e+01
# mean   2019-08-04 14:40:00    2155.611111    73.827778     6.784117e+08
# min    2012-01-01 00:00:00       2.000000    19.700000     6.552039e+07
# 25%    2017-04-14 00:00:00    1221.500000    25.250000     2.123722e+08
# 50%    2022-05-10 12:00:00    2175.500000    30.750000     3.753202e+08
# 75%    2022-05-13 00:00:00    3020.000000    42.850000     1.050746e+09
# max    2024-05-04 00:00:00    4470.000000   545.900000     2.226870e+09
# std                    NaN    1415.624541   125.923169     6.327132e+08
#
#        Spotify Popularity  Apple Music Playlist Count  Deezer Playlist Count  \
# count           17.000000                   18.000000              18.000000
# mean            74.411765                   93.722222              31.277778
# min             59.000000                    5.000000               3.000000
# 25%             71.000000                   23.250000               7.250000
# 50%             74.000000                   63.500000              24.000000
# 75%             79.000000                  150.500000              44.500000
# max             92.000000                  357.000000             111.000000
# std              7.984820                   91.825157              29.381478
#
#        Amazon Playlist Count  TIDAL Popularity
# count              18.000000               0.0
# mean               34.388889               NaN
# min                 6.000000               NaN
# 25%                22.000000               NaN
# 50%                25.500000               NaN
# 75%                37.000000               NaN
# max               111.000000               NaN
# std                27.685500               NaN

# %%
file_upload.head(5)
# Out:
#                         Track                    Album Name          Artist  \
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC  All Time Rank  Track Score  Spotify Streams  \
# 0   2024-04-26  QM24S2402528              1        725.4     3.904709e+08
# 1   2024-05-04  USUG12400910              2        545.9     3.237039e+08
# 2   2024-03-19  QZJ842400387              3        538.4     6.013093e+08
# 3   2023-01-12  USSM12209777              4        444.9     2.031281e+09
# 4   2024-05-31  USUG12403398              5        423.3     1.070349e+08
#
#   Spotify Playlist Count Spotify Playlist Reach  ...  SiriusXM Spins  \
# 0                30716.0            196631588.0  ...           684.0
# 1                28113.0            174597137.0  ...             3.0
# 2                54331.0            211607669.0  ...           536.0
# 3               269802.0            136569078.0  ...          2182.0
# 4                 7223.0            151469874.0  ...             1.0
#
#   Deezer Playlist Count Deezer Playlist Reach Amazon Playlist Count  \
# 0                  62.0            17598718.0                 114.0
# 1                  67.0            10422430.0                 111.0
# 2                 136.0            36321847.0                 172.0
# 3                 264.0            24684248.0                 210.0
# 4                  82.0            17660624.0                 105.0
#
#   Pandora Streams Pandora Track Stations Soundcloud Streams  Shazam Counts  \
# 0      18004655.0                22931.0          4818457.0      2669262.0
# 1       7780028.0                28444.0          6623075.0      1118279.0
# 2       5022621.0                 5639.0          7208651.0      5285340.0
# 3     190260277.0               203384.0                  0     11822942.0
# 4       4493884.0                 7006.0           207179.0       457017.0
#
#   TIDAL Popularity Explicit Track
# 0              NaN          False
# 1              NaN           True
# 2              NaN          False
# 3              NaN          False
# 4              NaN           True
#
# [5 rows x 29 columns]

# %%
topfive = file_upload.head(5)

# %%
topfive.describe()
# Out:
#               Release Date  All Time Rank  Track Score  Spotify Streams  \
# count                    5       5.000000     5.000000     5.000000e+00
# mean   2024-01-24 00:00:00       3.000000   535.580000     6.907599e+08
# min    2023-01-12 00:00:00       1.000000   423.300000     1.070349e+08
# 25%    2024-03-19 00:00:00       2.000000   444.900000     3.237039e+08
# 50%    2024-04-26 00:00:00       3.000000   538.400000     3.904709e+08
# 75%    2024-05-04 00:00:00       4.000000   545.900000     6.013093e+08
# max    2024-05-31 00:00:00       5.000000   725.400000     2.031281e+09
# std                    NaN       1.581139   119.347966     7.698434e+08
#
#        Spotify Popularity  Apple Music Playlist Count  Deezer Playlist Count  \
# count            5.000000                    5.000000                 5.0000
# mean            89.800000                  232.800000               122.2000
# min             85.000000                  182.000000                62.0000
# 25%             88.000000                  188.000000                67.0000
# 50%             92.000000                  190.000000                82.0000
# 75%             92.000000                  210.000000               136.0000
# max             92.000000                  394.000000               264.0000
# std              3.193744                   90.725961                84.5352
#
#        Amazon Playlist Count  TIDAL Popularity
# count               5.000000               0.0
# mean              142.400000               NaN
# min               105.000000               NaN
# 25%               111.000000               NaN
# 50%               114.000000               NaN
# 75%               172.000000               NaN
# max               210.000000               NaN
# std                46.468269               NaN

# %%
file_upload.head(5).describe()
# Out:
#               Release Date  All Time Rank  Track Score  Spotify Streams  \
# count                    5       5.000000     5.000000     5.000000e+00
# mean   2024-01-24 00:00:00       3.000000   535.580000     6.907599e+08
# min    2023-01-12 00:00:00       1.000000   423.300000     1.070349e+08
# 25%    2024-03-19 00:00:00       2.000000   444.900000     3.237039e+08
# 50%    2024-04-26 00:00:00       3.000000   538.400000     3.904709e+08
# 75%    2024-05-04 00:00:00       4.000000   545.900000     6.013093e+08
# max    2024-05-31 00:00:00       5.000000   725.400000     2.031281e+09
# std                    NaN       1.581139   119.347966     7.698434e+08
#
#        Spotify Popularity  Apple Music Playlist Count  Deezer Playlist Count  \
# count            5.000000                    5.000000                 5.0000
# mean            89.800000                  232.800000               122.2000
# min             85.000000                  182.000000                62.0000
# 25%             88.000000                  188.000000                67.0000
# 50%             92.000000                  190.000000                82.0000
# 75%             92.000000                  210.000000               136.0000
# max             92.000000                  394.000000               264.0000
# std              3.193744                   90.725961                84.5352
#
#        Amazon Playlist Count  TIDAL Popularity
# count               5.000000               0.0
# mean              142.400000               NaN
# min               105.000000               NaN
# 25%               111.000000               NaN
# 50%               114.000000               NaN
# 75%               172.000000               NaN
# max               210.000000               NaN
# std                46.468269               NaN

# %%
import matplotlib.pyplot as plt

# %%
data_subset = file_upload.Artist.value_counts().head(10)
print(data_subset)
# Out:
# Artist
# Drake            63
# Taylor Swift     63
# Bad Bunny        60
# KAROL G          32
# The Weeknd       31
# Travis Scott     30
# Billie Eilish    27
# Ariana Grande    26
# Future           23
# Peso Pluma       22
# Name: count, dtype: int64

# %%
drake = file_upload['Artist']

# %%
data_subset.plot(kind = 'bar', color = 'blue')
plt.title('Top 10 Artist')
plt.ylabel('Count')
plt.show()

# %%
explicit_counts = file_upload['Explicit Track'].value_counts()
print(explicit_counts)
# Out:
# Explicit Track
# False    2949
# True     1651
# Name: count, dtype: int64

# %%
plt.pie(explicit_counts, labels = ['Non-explicit', 'Explicit'], autopct = '%1.2f%%', colors = ['grey', 'red'])
plt.title('Explicit vs Non-Explicit Tracks')
plt.show()

# %%
import seaborn as sns

# %%
file_upload['Year'] = file_upload['Release Date'].dt.year
print(file_upload['Year'].head())
# Out:
# 0    2024
# 1    2024
# 2    2024
# 3    2023
# 4    2024
# Name: Year, dtype: int32

# %%
sns.histplot(data=file_upload, x="Year")
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
sns.histplot(data=file_upload, x="Year", kde=True, discrete=True)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
file_upload['Month'] = file_upload['Release Date'].dt.month

# %%
sns.histplot(data=file_upload, x="Month", kde=True, discrete=True, color = 'green')
# Out:
# <Axes: xlabel='Month', ylabel='Count'>

# %%
print(file_upload['Month'].value_counts())
# Out:
# Month
# 5     511
# 1     503
# 3     430
# 4     420
# 6     395
# 10    384
# 2     371
# 11    350
# 9     328
# 7     321
# 8     315
# 12    272
# Name: count, dtype: int64

# %%
print(file_upload['Month'].mode())
# Out:
# 0    5
# Name: Month, dtype: int32

# %%
sns.boxplot(data=file_upload, x="Track Score")
# Out:
# <Axes: xlabel='Track Score'>

# %%
numeric_df = file_upload.select_dtypes(include = ['float64', 'int32'])
corr_matrix = numeric_df.corr()
print(corr_matrix)
# Out:
#                             Track Score  Spotify Streams  Spotify Popularity  \
# Track Score                    1.000000         0.244176            0.192808
# Spotify Streams                0.244176         1.000000            0.363172
# Spotify Popularity             0.192808         0.363172            1.000000
# Apple Music Playlist Count     0.402765         0.744640            0.288430
# Deezer Playlist Count          0.337561         0.645145            0.238246
# Amazon Playlist Count          0.548705         0.455462            0.320260
# TIDAL Popularity                    NaN              NaN                 NaN
# Year                           0.126693        -0.556165           -0.142739
# Month                         -0.031149        -0.049758           -0.027578
#
#                             Apple Music Playlist Count  Deezer Playlist Count  \
# Track Score                                   0.402765               0.337561
# Spotify Streams                               0.744640               0.645145
# Spotify Popularity                            0.288430               0.238246
# Apple Music Playlist Count                    1.000000               0.775710
# Deezer Playlist Count                         0.775710               1.000000
# Amazon Playlist Count                         0.665635               0.568904
# TIDAL Popularity                                   NaN                    NaN
# Year                                         -0.383402              -0.324647
# Month                                        -0.073504              -0.059370
#
#                             Amazon Playlist Count  TIDAL Popularity      Year  \
# Track Score                              0.548705               NaN  0.126693
# Spotify Streams                          0.455462               NaN -0.556165
# Spotify Popularity                       0.320260               NaN -0.142739
# Apple Music Playlist Count               0.665635               NaN -0.383402
# Deezer Playlist Count                    0.568904               NaN -0.324647
# Amazon Playlist Count                    1.000000               NaN -0.120338
# TIDAL Popularity                              NaN               NaN       NaN
# Year                                    -0.120338               NaN  1.000000
# Month                                   -0.090836               NaN  0.013849
#
#                                Month
# Track Score                -0.031149
# Spotify Streams            -0.049758
# Spotify Popularity         -0.027578
# Apple Music Playlist Count -0.073504
# Deezer Playlist Count      -0.059370
# Amazon Playlist Count      -0.090836
# TIDAL Popularity                 NaN
# Year                        0.013849
# Month                       1.000000

# %%
plt.figure(figsize = (20, 10))
sns.color_palette("coolwarm", as_cmap=True)

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix of Numeric Features')
plt.show()

# %%
tfifty = file_upload.head(50)

# %%
pivot = pd.pivot_table(data = tfifty, index = 'Track', columns='Year', values='Track Score', aggfunc='sum')
print(pivot)
# Out:
# Year                                                 2015   2017   2019  \
# Track
# A Bar Song (Tipsy)                                    NaN    NaN    NaN
# As It Was                                             NaN    NaN    NaN
# BAND4BAND (feat. Lil Baby)                            NaN    NaN    NaN
# BIRDS OF A FEATHER                                    NaN    NaN    NaN
# BLUE                                                  NaN    NaN    NaN
# Baby Shark                                          265.7    NaN    NaN
# Beat Automotivo Tan Tan Tan Viral                     NaN    NaN    NaN
# Beautiful Things                                      NaN    NaN    NaN
# Cupid ï¿½ï¿½ï¿½ Twin Ver. (FIFTY FIFTY) ï¿½ï¿½ï...    NaN    NaN    NaN
# Dance Monkey                                          NaN    NaN  214.5
# Danza Kuduro - Cover                                  NaN    NaN    NaN
# Daylight                                              NaN    NaN    NaN
# Despacito                                             NaN  203.5    NaN
# Espresso                                              NaN    NaN    NaN
# Flowers                                               NaN    NaN    NaN
# Fortnight (feat. Post Malone)                         NaN    NaN    NaN
# Future                                                NaN    NaN    NaN
# Gata Only                                             NaN    NaN    NaN
# Houdini                                               NaN    NaN    NaN
# I Had Some Help (feat. Morgan Wallen)                 NaN    NaN    NaN
# I'm Good (Blue)                                       NaN    NaN    NaN
# If We Ever Broke Up                                   NaN    NaN    NaN
# LALA                                                  NaN    NaN    NaN
# LUNCH                                                 NaN    NaN    NaN
# Like That                                             NaN    NaN    NaN
# Lose Control                                          NaN    NaN    NaN
# Lovin On Me                                           NaN    NaN    NaN
# MILLION DOLLAR BABY                                   NaN    NaN    NaN
# My Love Mine All Mine                                 NaN    NaN    NaN
# Not Like Us                                           NaN    NaN    NaN
# Numb / Encore                                         NaN    NaN    NaN
# Paint The Town Red                                    NaN    NaN    NaN
# Please Please Please                                  NaN    NaN    NaN
# SHEESH                                                NaN    NaN    NaN
# STAY (with Justin Bieber)                             NaN    NaN    NaN
# Strangers                                             NaN    NaN    NaN
# TEXAS HOLD 'EM                                        NaN    NaN    NaN
# The Door                                              NaN    NaN    NaN
# Too Sweet                                             NaN    NaN    NaN
# Water                                                 NaN    NaN    NaN
# What's Love Got to Do with It - 2023 Remaster         NaN    NaN    NaN
# bathroom floor                                        NaN    NaN    NaN
# fukumean                                              NaN    NaN    NaN
# greedy                                                NaN    NaN    NaN
# i like the way you kiss me                            NaN    NaN    NaN
# we can't be friends (wait for your love)              NaN    NaN    NaN
#
# Year                                                 2021   2022   2023  \
# Track
# A Bar Song (Tipsy)                                    NaN    NaN    NaN
# As It Was                                             NaN  292.0    NaN
# BAND4BAND (feat. Lil Baby)                            NaN    NaN    NaN
# BIRDS OF A FEATHER                                    NaN    NaN    NaN
# BLUE                                                  NaN    NaN    NaN
# Baby Shark                                            NaN    NaN    NaN
# Beat Automotivo Tan Tan Tan Viral                     NaN  268.1    NaN
# Beautiful Things                                      NaN    NaN    NaN
# Cupid ï¿½ï¿½ï¿½ Twin Ver. (FIFTY FIFTY) ï¿½ï¿½ï...    NaN    NaN  211.2
# Dance Monkey                                          NaN    NaN    NaN
# Danza Kuduro - Cover                                  NaN    NaN    NaN
# Daylight                                              NaN    NaN  207.0
# Despacito                                             NaN    NaN    NaN
# Espresso                                              NaN    NaN    NaN
# Flowers                                               NaN    NaN  444.9
# Fortnight (feat. Post Malone)                         NaN    NaN    NaN
# Future                                                NaN    NaN    NaN
# Gata Only                                             NaN    NaN    NaN
# Houdini                                               NaN    NaN  205.1
# I Had Some Help (feat. Morgan Wallen)                 NaN    NaN    NaN
# I'm Good (Blue)                                       NaN  209.6    NaN
# If We Ever Broke Up                                   NaN    NaN  203.6
# LALA                                                  NaN    NaN  299.9
# LUNCH                                                 NaN    NaN    NaN
# Like That                                             NaN    NaN    NaN
# Lose Control                                          NaN    NaN  224.1
# Lovin On Me                                           NaN    NaN  410.1
# MILLION DOLLAR BABY                                   NaN    NaN    NaN
# My Love Mine All Mine                                 NaN    NaN  206.2
# Not Like Us                                           NaN    NaN    NaN
# Numb / Encore                                         NaN    NaN    NaN
# Paint The Town Red                                    NaN    NaN  290.5
# Please Please Please                                  NaN    NaN    NaN
# SHEESH                                                NaN    NaN    NaN
# STAY (with Justin Bieber)                           266.3    NaN    NaN
# Strangers                                             NaN    NaN  233.5
# TEXAS HOLD 'EM                                        NaN    NaN    NaN
# The Door                                              NaN    NaN    NaN
# Too Sweet                                             NaN    NaN    NaN
# Water                                                 NaN    NaN  234.6
# What's Love Got to Do with It - 2023 Remaster         NaN    NaN    NaN
# bathroom floor                                        NaN  301.6    NaN
# fukumean                                              NaN    NaN  221.1
# greedy                                                NaN    NaN  293.7
# i like the way you kiss me                            NaN    NaN    NaN
# we can't be friends (wait for your love)              NaN    NaN    NaN
#
# Year                                                  2024
# Track
# A Bar Song (Tipsy)                                   226.4
# As It Was                                              NaN
# BAND4BAND (feat. Lil Baby)                           330.6
# BIRDS OF A FEATHER                                   212.8
# BLUE                                                 292.6
# Baby Shark                                             NaN
# Beat Automotivo Tan Tan Tan Viral                      NaN
# Beautiful Things                                     407.2
# Cupid ï¿½ï¿½ï¿½ Twin Ver. (FIFTY FIFTY) ï¿½ï¿½ï...     NaN
# Dance Monkey                                           NaN
# Danza Kuduro - Cover                                1088.9
# Daylight                                               NaN
# Despacito                                              NaN
# Espresso                                             281.5
# Flowers                                                NaN
# Fortnight (feat. Post Malone)                        297.6
# Future                                               277.5
# Gata Only                                            375.8
# Houdini                                              423.3
# I Had Some Help (feat. Morgan Wallen)                322.1
# I'm Good (Blue)                                        NaN
# If We Ever Broke Up                                    NaN
# LALA                                                   NaN
# LUNCH                                                316.3
# Like That                                            308.2
# Lose Control                                           NaN
# Lovin On Me                                            NaN
# MILLION DOLLAR BABY                                  725.4
# My Love Mine All Mine                                  NaN
# Not Like Us                                          545.9
# Numb / Encore                                        256.0
# Paint The Town Red                                     NaN
# Please Please Please                                 205.7
# SHEESH                                               237.5
# STAY (with Justin Bieber)                              NaN
# Strangers                                              NaN
# TEXAS HOLD 'EM                                       278.9
# The Door                                             320.2
# Too Sweet                                            231.6
# Water                                                  NaN
# What's Love Got to Do with It - 2023 Remaster        230.0
# bathroom floor                                         NaN
# fukumean                                               NaN
# greedy                                                 NaN
# i like the way you kiss me                           538.4
# we can't be friends (wait for your love)             262.8

# %%
sns.heatmap(pivot, cmap='YlGnBu')
plt.title('Best Track score in the year')
plt.show()

# %%
file_upload.dtypes
# Out:
# Track                                 object
# Album Name                            object
# Artist                                object
# Release Date                  datetime64[ns]
# ISRC                                  object
# All Time Rank                          int16
# Track Score                          float64
# Spotify Streams                      float64
# Spotify Playlist Count                object
# Spotify Playlist Reach                object
# Spotify Popularity                   float64
# YouTube Views                         object
# YouTube Likes                         object
# TikTok Posts                          object
# TikTok Likes                          object
# TikTok Views                          object
# YouTube Playlist Reach                object
# Apple Music Playlist Count           float64
# AirPlay Spins                         object
# SiriusXM Spins                        object
# Deezer Playlist Count                float64
# Deezer Playlist Reach                 object
# Amazon Playlist Count                float64
# Pandora Streams                       object
# Pandora Track Stations                object
# Soundcloud Streams                    object
# Shazam Counts                         object
# TIDAL Popularity                     float64
# Explicit Track                          bool
# Year                                   int32
# Month                                  int32
# dtype: object

# %%
file_upload.head(50)
# Out:
#                                                 Track  \
# 0                                 MILLION DOLLAR BABY
# 1                                         Not Like Us
# 2                          i like the way you kiss me
# 3                                             Flowers
# 4                                             Houdini
# 5                                         Lovin On Me
# 6                                    Beautiful Things
# 7                                           Gata Only
# 8                                Danza Kuduro - Cover
# 9                          BAND4BAND (feat. Lil Baby)
# 10              I Had Some Help (feat. Morgan Wallen)
# 11                                           The Door
# 12                                              LUNCH
# 13                                          Like That
# 14                                     bathroom floor
# 15                                               LALA
# 16                      Fortnight (feat. Post Malone)
# 17                                             greedy
# 18                                               BLUE
# 19                                          As It Was
# 20                                 Paint The Town Red
# 21                                           Espresso
# 22                               Danza Kuduro - Cover
# 23                                     TEXAS HOLD 'EM
# 24                                             Future
# 25                  Beat Automotivo Tan Tan Tan Viral
# 26                          STAY (with Justin Bieber)
# 27                                         Baby Shark
# 28           we can't be friends (wait for your love)
# 29                                      Numb / Encore
# 30                               Danza Kuduro - Cover
# 31                                             SHEESH
# 32                                              Water
# 33                                          Strangers
# 34                                          Too Sweet
# 35      What's Love Got to Do with It - 2023 Remaster
# 36                                 A Bar Song (Tipsy)
# 37                                       Lose Control
# 38                                           fukumean
# 39                                       Dance Monkey
# 40                                 BIRDS OF A FEATHER
# 41  Cupid ï¿½ï¿½ï¿½ Twin Ver. (FIFTY FIFTY) ï¿½ï¿½...
# 42                                    I'm Good (Blue)
# 43                                           Daylight
# 44                              My Love Mine All Mine
# 45                               Please Please Please
# 46                                            Houdini
# 47                               Danza Kuduro - Cover
# 45             9883.0       47115.0              NaN            True  2024
# 46          1991527.0     2389957.0              NaN           False  2023
# 47                  0             0              NaN            True  2024
# 48                  0     2227494.0              NaN            True  2023
# 49                  0    19622551.0              NaN           False  2017
#
#    Month
# 0      4
# 1      5
# 2      3
# 3      1
# 4      5
# 5     11
# 6      1
# 7      2
# 8      6
# 9      5
# 10     5
# 11     6
# 12     5
# 13     3
# 14    10
# 15     3
# 16     4
# 17     9
# 18     5
# 19     3
# 20     8
# 21     4
# 22     5
# 23     2
# 24     1
# 25     5
# 26     7
# 27    12
# 28     3
# 29     4
# 30     5
# 31     4
# 32     7
# 33     9
# 34     3
# 35     4
# 36     4
# 37     6
# 38     6
# 39     5
# 40     5
# 41     4
# 42     8
# 43     4
# 44     9
# 45     6
# 46    11
# 47     5
# 48     2
# 49     1
#
# [50 rows x 31 columns]

# %%
file_upload.dtypes
# Out:
# Track                                 object
# Album Name                            object
# Artist                                object
# Release Date                  datetime64[ns]
# ISRC                                  object
# All Time Rank                          int16
# Track Score                          float64
# Spotify Streams                      float64
# Spotify Playlist Count                object
# Spotify Playlist Reach                object
# Spotify Popularity                   float64
# YouTube Views                         object
# YouTube Likes                         object
# TikTok Posts                          object
# TikTok Likes                          object
# TikTok Views                          object
# YouTube Playlist Reach                object
# Apple Music Playlist Count           float64
# AirPlay Spins                         object
# SiriusXM Spins                        object
# Deezer Playlist Count                float64
# Deezer Playlist Reach                 object
# Amazon Playlist Count                float64
# Pandora Streams                       object
# Pandora Track Stations                object
# Soundcloud Streams                    object
# Shazam Counts                         object
# TIDAL Popularity                     float64
# Explicit Track                          bool
# Year                                   int32
# Month                                  int32
# dtype: object

# %%
platforms = ['Shazam Counts', 'Soundcloud Streams', 'Pandora Streams', 'YouTube Views', 'TikTok Views', 'Spotify Streams']

# %%
file_upload[['Shazam Counts', 'Soundcloud Streams', 'Pandora Streams', 'YouTube Views', 'TikTok Views', 'Spotify Streams']].dtypes
# Out:
# Shazam Counts          object
# Soundcloud Streams     object
# Pandora Streams        object
# YouTube Views          object
# TikTok Views           object
# Spotify Streams       float64
# dtype: object

# %%
filters = file_upload[['Shazam Counts', 'Soundcloud Streams', 'Pandora Streams', 'YouTube Views', 'TikTok Views', 'Spotify Streams']]

# %%
filters = filters.replace(',','', regex=True)

# %%
filters = filters.astype(int)
print(filters.dtype)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [138], line 2
#       1 filters = filters.astype(int)
# ----> 2 print(filters.dtype)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
file_upload[['Shazam Counts', 'Soundcloud Streams', 'Pandora Streams', 'YouTube Views', 'TikTok Views', 'Spotify Streams']].dtypes
# Out:
# Shazam Counts          object
# Soundcloud Streams     object
# Pandora Streams        object
# YouTube Views          object
# TikTok Views           object
# Spotify Streams       float64
# dtype: object

# %%
m = file_upload['Shazam Counts']
print(type(m[1])
# Out:
#   Cell In [140], line 2
#     print(type(m[1])
#                     ^
# SyntaxError: incomplete input
